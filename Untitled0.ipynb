# %% [markdown]
# <a href="https://colab.research.google.com/github/Prathithchandra/Healthify/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/content/sample_data/cherry.jpg",0)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=1791x2652>

# %%
cv2.imwrite("save_cherry.jpg",img)
# Out:
# True
